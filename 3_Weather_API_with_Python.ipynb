# %% [markdown]
# <a href="https://colab.research.google.com/github/mqtmnd-stack/lab-python-data-structures/blob/main/3_Weather_API_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# #  OpenWeatherMap API 🌦️

# %% [markdown]
# In this challenge, we will use OpenWeatherMap API to retrieve extract temperature forecasts for any city around the globe 🌡️

# %% [markdown]
# ## Read the documentation

# %% [markdown]
# When presented with a new API to use, your first reflex should be to go straight to the documentation, and figure out the following:
#
# - Does it output JSON?
# - Does this API require authentication? (do I need to sign up to get an API key? Do I need to pay?)
# - Which endpoints can I call? What data does it return?
#
#
#
# (Go back to the `API 101` lecture from week 3 if you are confused about some of the above terms)
#
#
# 👯‍♂️ Buddy time! Go to [OpenWeatherMap API documentation](https://openweathermap.org/api) read it, and try answering those questions. When you are comfortable with what this API is about, you can start working on the challenge.

# %% [markdown]
# ## Authentication (and a small 🎁 from us)

# %% [markdown]
# You might have noticed that OpenWeatherMap requires you to sign up for an API key. Even though OpenWeatherMap offers a [few free API calls](https://openweathermap.org/price), they still want to know how different users consume the API (and track if you hit your API call limit 😜). This is the norm for most APIs out there.
#
#
# You can either:
#
# - Sign up for an API key (which might take 10-20 minutes to get activated)
# - Use a proxy we created for you 👉 https://weather.lewagon.com/. This URL already includes the API key, so you can just replace the host of OpenWeatherMap with the Le Wagon website and skip the API key parameter in your request. For example:
#
# `https://api.openweathermap.org/geo/1.0/direct?q=Barcelona&appid=XXXXXXXXXXX`
#
# becomes:
#
# `https://weather.lewagon.com/geo/1.0/direct?q=Barcelona`
#
# **Note**: make sure to check https://weather.lewagon.com/ to see the documentation on which endpoints are proxied (if you get a Forbidden error copy and paste the link in a new tab!). Try to click on one of the examples displayed to make sure that you can run API calls succesfully.
#
#
# If the endpoint you want to access is not shown, you will need to access it with your own API key instead.

# %% [markdown]
# ## Make some API calls

# %% [markdown]
# ### With the browser

# %% [markdown]
# Have a look at the following link.
#
# <code>https://weather.lewagon.com/geo/1.0/direct?q=Paris</code>
#
# Is it a little hard to read ? If you are using Google Chrome, we recommend you to install the [JSONVue extension](https://chromewebstore.google.com/detail/jsonvue/chklaanhfefbnpoihckbnefhakgolnmc), it will make reading JSON on your browser much easier.
# Once installed, reload the page, and admire the difference !

# %% [markdown]
# ### With Python

# %% [markdown]
# Now it's your turn to code ! \
# Use the `requests`library and load the data for the city of Paris in a variable called `paris_info`and print it. \
# This should look exactly the same as in your browser.

# %% [markdown]
# <details>
#     <summary>Hint 🔍</summary>
#
# Do not copy the whole URL provided above, try to use `params` argument of the `requests.get()`method instead.
#
# </details>

# %%
import requests
paris_info = requests.get("https://weather.lewagon.com/geo/1.0/direct", params={"q":"Paris"}).json()
paris_info
# Out:
# [{'name': 'Paris',
#   'local_names': {'ja': 'パリ',
#    'cs': 'Paříž',
#    'ps': 'پاريس',
#    'es': 'París',
#    'eu': 'Paris',
#    'ht': 'Pari',
#    'ur': 'پیرس',
#    'sh': 'Pariz',
#    'sc': 'Parigi',
#    'pa': 'ਪੈਰਿਸ',
#    'my': 'ပါရီမြို့',
#    'pl': 'Paryż',
#    'tg': 'Париж',
#    'sk': 'Paríž',
#    'la': 'Lutetia',
#    'vi': 'Paris',
#    'el': 'Παρίσι',
#    'hy': 'Փարիզ',
#    'he': 'פריז',
#    'ka': 'პარიზი',
#    'mk': 'Париз',
#    'yi': 'פאריז',
#    'bg': 'Париж',
#    'wo': 'Pari',
#    'no': 'Paris',
#    'kk': 'Париж',
#    'ug': 'پارىژ',
#    'ha': 'Pariis',
#    'bs': 'Pariz',
#    'zu': 'IParisi',
#    'ko': '파리',
#    'af': 'Parys',
#    'so': 'Baariis',
#    'bn': 'প্যারিস',
#    'br': 'Pariz',
#    'sv': 'Paris',
#    'li': 'Paries',
#    'fa': 'پاریس',
#    'ar': 'باريس',
#    'tk': 'Pariž',
#    'fy': 'Parys',
#    'or': 'ପ୍ୟାରିସ',
#    'be': 'Парыж',
#    'is': 'París',
#    'bo': 'ཕ་རི།',
#    'lt': 'Paryžius',
#    'hi': 'पैरिस',
#    'tt': 'Париж',
#    'ne': 'पेरिस',
#    'ca': 'París',
#    'gu': 'પૅરિસ',
#    'lv': 'Parīze',
#    'yo': 'Parisi',
#    'gn': 'Parĩ',
#    'de': 'Paris',
#    'kv': 'Париж',
#    'mr': 'पॅरिस',
#    'oc': 'París',
#    'an': 'París',
#    'co': 'Parighji',
#    'gv': 'Paarys',
#    'et': 'Pariis',
#    'os': 'Париж',
#    'mn': 'Парис',
#    'zh': '巴黎',
#    'cu': 'Парижь',
#    'fi': 'Pariisi',
#    'tl': 'Paris',
#    'km': 'ប៉ារីស',
#    'hu': 'Párizs',
#    'it': 'Parigi',
#    'ta': 'பாரிஸ்',
#    'fr': 'Paris',
#    'wa': 'Paris',
#    'ku': 'Parîs',
#    'ba': 'Париж',
#    'kn': 'ಪ್ಯಾರಿಸ್',
#    'cv': 'Парис',
#    'am': 'ፓሪስ',
#    'nl': 'Parijs',
#    'uz': 'Parij',
#    'ru': 'Париж',
#    'eo': 'Parizo',
#    'ky': 'Париж',
#    'hr': 'Pariz',
#    'uk': 'Париж',
#    'th': 'ปารีส',
#    'mi': 'Parī',
#    'ga': 'Páras',
#    'za': 'Bahliz',
#    'lb': 'Paräis',
#    'sr': 'Париз',
#    'sl': 'Pariz',
#    'gl': 'París',
#    'ml': 'പാരിസ്',
#    'ln': 'Pari',
#    'te': 'పారిస్',
#    'sq': 'Parisi'},
#   'lat': 48.8588897,
#   'lon': 2.3200410217200766,
#   'country': 'FR',
#   'state': 'Ile-de-France'}]

# %% [markdown]
# What is the type of `paris_info`?

# %%
type(paris_info)
# Out:
# list

# %% [markdown]
# 🎉 Congratulations, you just made your first API call with Python!

# %% [markdown]
# ### Retrieve specific information

# %% [markdown]
# Using your `paris_info`variable, retrieve the latitude and longitude of Paris and store them in a list named `paris_coordinates`

# %%
paris_info = requests.get("https://weather.lewagon.com/geo/1.0/direct", params={"q":"Paris"}).json()
paris_coordinates = [paris_info[0]["lat"],paris_info[0]["lon"]]
paris_coordinates
# Out:
# [48.8588897, 2.3200410217200766]

# %% [markdown]
# Finally, create a `get_coordinates`function that will take a city name as argument and return its coordinates in a list.

# %% [markdown]
# ## Weather Forecasts

# %% [markdown]
# ### Paris forecasts

# %% [markdown]
# Go back to the documentation, and find an endpoint you can use to get weather forecasts data.

# %% [markdown]
# <details>
#     <summary>Hint 🔍</summary>
#
# The proxy provided by Le Wagon has a `forecast` endpoint.
#
# </details>

# %% [markdown]
# What are the `query parameters` we need to get that information? \
# Using that endpoint, store the weather forecasts of Paris in a variable named `paris_forecasts`.

# %% [markdown]
# <details>
#     <summary>Hint 🔍</summary>
#
# You can re-use your `get_coordinates` function.
#
# </details>

# %%
lat, lon = get_coordinates("Paris")
paris_forecasts = requests.get("https://weather.lewagon.com/data/2.5/forecast",params={"lat":lat,"lon":lon}).json()["list"]
paris_forecasts
# Out:
# [{'dt': 1779289200,
#   'main': {'temp': 301.14,
#    'feels_like': 304.92,
#    'temp_min': 301.09,
#    'temp_max': 301.14,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1011,
#    'humidity': 78,
#    'temp_kf': 0.05},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 12},
#   'wind': {'speed': 8.54, 'deg': 221, 'gust': 10.1},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.15},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-20 15:00:00'},
#  {'dt': 1779300000,
#   'main': {'temp': 301.08,
#    'feels_like': 304.63,
#    'temp_min': 301.04,
#    'temp_max': 301.08,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1013,
#    'humidity': 77,
#    'temp_kf': 0.04},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 8.38, 'deg': 223, 'gust': 9.85},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-20 18:00:00'},
#  {'dt': 1779310800,
#   'main': {'temp': 301.04,
#    'feels_like': 304.69,
#    'temp_min': 301.04,
#    'temp_max': 301.04,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 8.07, 'deg': 225, 'gust': 9.46},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.19},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-20 21:00:00'},
#  {'dt': 1779321600,
#   'main': {'temp': 301.06,
#    'feels_like': 304.45,
#    'temp_min': 301.06,
#    'temp_max': 301.06,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1011,
#    'humidity': 76,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 8.63, 'deg': 218, 'gust': 10.55},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.12},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-21 00:00:00'},
#  {'dt': 1779332400,
#   'main': {'temp': 300.98,
#    'feels_like': 304.69,
#    'temp_min': 300.98,
#    'temp_max': 300.98,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 9.21, 'deg': 213, 'gust': 10.46},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-21 03:00:00'},
#  {'dt': 1779343200,
#   'main': {'temp': 300.98,
#    'feels_like': 304.69,
#    'temp_min': 300.98,
#    'temp_max': 300.98,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 9.5, 'deg': 211, 'gust': 11.3},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-21 06:00:00'},
#  {'dt': 1779354000,
#   'main': {'temp': 301.05,
#    'feels_like': 304.85,
#    'temp_min': 301.05,
#    'temp_max': 301.05,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 9.51, 'deg': 215, 'gust': 11.01},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-21 09:00:00'},
#  {'dt': 1779364800,
#   'main': {'temp': 300.92,
#    'feels_like': 304.01,
#    'temp_min': 300.92,
#    'temp_max': 300.92,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1011,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 55},
#   'wind': {'speed': 9.22, 'deg': 226, 'gust': 10.34},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-21 12:00:00'},
#  {'dt': 1779375600,
#   'main': {'temp': 300.98,
#    'feels_like': 304.41,
#    'temp_min': 300.98,
#    'temp_max': 300.98,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 12},
#   'wind': {'speed': 8.69, 'deg': 224, 'gust': 10.34},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-21 15:00:00'},
#  {'dt': 1779386400,
#   'main': {'temp': 301,
#    'feels_like': 304.88,
#    'temp_min': 301,
#    'temp_max': 301,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 9},
#   'wind': {'speed': 8.6, 'deg': 230, 'gust': 9.77},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-21 18:00:00'},
#  {'dt': 1779397200,
#   'main': {'temp': 300.9,
#    'feels_like': 304.36,
#    'temp_min': 300.9,
#    'temp_max': 300.9,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 4},
#   'wind': {'speed': 8.67, 'deg': 221, 'gust': 9.89},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-21 21:00:00'},
#  {'dt': 1779408000,
#   'main': {'temp': 300.79,
#    'feels_like': 303.85,
#    'temp_min': 300.79,
#    'temp_max': 300.79,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 76,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 9},
#   'wind': {'speed': 9.78, 'deg': 221, 'gust': 11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-22 00:00:00'},
#  {'dt': 1779418800,
#   'main': {'temp': 300.79,
#    'feels_like': 303.85,
#    'temp_min': 300.79,
#    'temp_max': 300.79,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 76,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 49},
#   'wind': {'speed': 9.54, 'deg': 216, 'gust': 10.68},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-22 03:00:00'},
#  {'dt': 1779429600,
#   'main': {'temp': 300.91,
#    'feels_like': 304.52,
#    'temp_min': 300.91,
#    'temp_max': 300.91,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 30},
#   'wind': {'speed': 9.86, 'deg': 214, 'gust': 11.61},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-22 06:00:00'},
#  {'dt': 1779440400,
#   'main': {'temp': 301,
#    'feels_like': 305.17,
#    'temp_min': 301,
#    'temp_max': 301,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 27},
#   'wind': {'speed': 9.41, 'deg': 216, 'gust': 11.36},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-22 09:00:00'},
#  {'dt': 1779451200,
#   'main': {'temp': 300.86,
#    'feels_like': 304.54,
#    'temp_min': 300.86,
#    'temp_max': 300.86,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1011,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 19},
#   'wind': {'speed': 9.59, 'deg': 229, 'gust': 11.33},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-22 12:00:00'},
#  {'dt': 1779462000,
#   'main': {'temp': 300.94,
#    'feels_like': 304.59,
#    'temp_min': 300.94,
#    'temp_max': 300.94,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 21},
#   'wind': {'speed': 9.04, 'deg': 224, 'gust': 10.61},
#   'visibility': 10000,
#   'pop': 0.02,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-22 15:00:00'},
#  {'dt': 1779472800,
#   'main': {'temp': 300.94,
#    'feels_like': 304.32,
#    'temp_min': 300.94,
#    'temp_max': 300.94,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 57},
#   'wind': {'speed': 8.76, 'deg': 218, 'gust': 10.63},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-22 18:00:00'},
#  {'dt': 1779483600,
#   'main': {'temp': 300.88,
#    'feels_like': 304.58,
#    'temp_min': 300.88,
#    'temp_max': 300.88,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 63},
#   'wind': {'speed': 9.55, 'deg': 216, 'gust': 11.65},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-22 21:00:00'},
#  {'dt': 1779494400,
#   'main': {'temp': 300.76,
#    'feels_like': 304.17,
#    'temp_min': 300.76,
#    'temp_max': 300.76,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 69},
#   'wind': {'speed': 10.37, 'deg': 207, 'gust': 11.63},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-23 00:00:00'},
#  {'dt': 1779505200,
#   'main': {'temp': 300.81,
#    'feels_like': 304.28,
#    'temp_min': 300.81,
#    'temp_max': 300.81,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 10.58, 'deg': 205, 'gust': 12.94},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-23 03:00:00'},
#  {'dt': 1779516000,
#   'main': {'temp': 300.83,
#    'feels_like': 304.74,
#    'temp_min': 300.83,
#    'temp_max': 300.83,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 90},
#   'wind': {'speed': 11.11, 'deg': 202, 'gust': 14.07},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-23 06:00:00'},
#  {'dt': 1779526800,
#   'main': {'temp': 300.82,
#    'feels_like': 304.99,
#    'temp_min': 300.82,
#    'temp_max': 300.82,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 47},
#   'wind': {'speed': 9.96, 'deg': 207, 'gust': 13.19},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-23 09:00:00'},
#  {'dt': 1779537600,
#   'main': {'temp': 300.98,
#    'feels_like': 305.42,
#    'temp_min': 300.98,
#    'temp_max': 300.98,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1011,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 43},
#   'wind': {'speed': 9.02, 'deg': 212, 'gust': 11.1},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-23 12:00:00'},
#  {'dt': 1779548400,
#   'main': {'temp': 301.02,
#    'feels_like': 305.53,
#    'temp_min': 301.02,
#    'temp_max': 301.02,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 8.06, 'deg': 215, 'gust': 10.53},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.23},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-23 15:00:00'},
#  {'dt': 1779559200,
#   'main': {'temp': 301.01,
#    'feels_like': 305.2,
#    'temp_min': 301.01,
#    'temp_max': 301.01,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1015,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 82},
#   'wind': {'speed': 8.59, 'deg': 209, 'gust': 9.95},
#   'visibility': 10000,
#   'pop': 0.46,
#   'rain': {'3h': 0.4},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-23 18:00:00'},
#  {'dt': 1779570000,
#   'main': {'temp': 300.92,
#    'feels_like': 304.41,
#    'temp_min': 300.92,
#    'temp_max': 300.92,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 8.15, 'deg': 200, 'gust': 9.78},
#   'visibility': 10000,
#   'pop': 0.04,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-23 21:00:00'},
#  {'dt': 1779580800,
#   'main': {'temp': 300.9,
#    'feels_like': 304.5,
#    'temp_min': 300.9,
#    'temp_max': 300.9,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 89},
#   'wind': {'speed': 8.26, 'deg': 200, 'gust': 9.99},
#   'visibility': 10000,
#   'pop': 0.05,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-24 00:00:00'},
#  {'dt': 1779591600,
#   'main': {'temp': 300.78,
#    'feels_like': 304.61,
#    'temp_min': 300.78,
#    'temp_max': 300.78,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 93},
#   'wind': {'speed': 9.34, 'deg': 197, 'gust': 10.85},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-24 03:00:00'},
#  {'dt': 1779602400,
#   'main': {'temp': 300.8,
#    'feels_like': 304.94,
#    'temp_min': 300.8,
#    'temp_max': 300.8,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 9.68, 'deg': 193, 'gust': 11.48},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-24 06:00:00'},
#  {'dt': 1779613200,
#   'main': {'temp': 300.97,
#    'feels_like': 304.66,
#    'temp_min': 300.97,
#    'temp_max': 300.97,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 8.66, 'deg': 200, 'gust': 10.39},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-24 09:00:00'},
#  {'dt': 1779624000,
#   'main': {'temp': 301.1,
#    'feels_like': 305.12,
#    'temp_min': 301.1,
#    'temp_max': 301.1,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 87},
#   'wind': {'speed': 7.06, 'deg': 208, 'gust': 9.05},
#   'visibility': 10000,
#   'pop': 0.01,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-24 12:00:00'},
#  {'dt': 1779634800,
#   'main': {'temp': 300.97,
#    'feels_like': 305.09,
#    'temp_min': 300.97,
#    'temp_max': 300.97,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 6.32, 'deg': 226, 'gust': 8.07},
#   'visibility': 10000,
#   'pop': 0.59,
#   'rain': {'3h': 0.42},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-24 15:00:00'},
#  {'dt': 1779645600,
#   'main': {'temp': 300.94,
#    'feels_like': 304.87,
#    'temp_min': 300.94,
#    'temp_max': 300.94,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1015,
#    'humidity': 81,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 7.55, 'deg': 207, 'gust': 9.15},
#   'visibility': 10000,
#   'pop': 0.58,
#   'rain': {'3h': 0.5},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-24 18:00:00'},
#  {'dt': 1779656400,
#   'main': {'temp': 300.76,
#    'feels_like': 304.3,
#    'temp_min': 300.76,
#    'temp_max': 300.76,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 80},
#   'wind': {'speed': 8.47, 'deg': 210, 'gust': 9.47},
#   'visibility': 10000,
#   'pop': 0.55,
#   'rain': {'3h': 0.5},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-24 21:00:00'},
#  {'dt': 1779667200,
#   'main': {'temp': 300.34,
#    'feels_like': 303.53,
#    'temp_min': 300.34,
#    'temp_max': 300.34,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 82},
#   'wind': {'speed': 8.22, 'deg': 210, 'gust': 9.36},
#   'visibility': 10000,
#   'pop': 0.68,
#   'rain': {'3h': 0.41},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-05-25 00:00:00'},
#  {'dt': 1779678000,
#   'main': {'temp': 300.84,
#    'feels_like': 304.9,
#    'temp_min': 300.84,
#    'temp_max': 300.84,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 83},
#   'wind': {'speed': 8.86, 'deg': 199, 'gust': 10.92},
#   'visibility': 10000,
#   'pop': 0.06,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-25 03:00:00'},
#  {'dt': 1779688800,
#   'main': {'temp': 300.87,
#    'feels_like': 305.27,
#    'temp_min': 300.87,
#    'temp_max': 300.87,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1014,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 50},
#   'wind': {'speed': 9.68, 'deg': 193, 'gust': 11.9},
#   'visibility': 10000,
#   'pop': 0.04,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-25 06:00:00'},
#  {'dt': 1779699600,
#   'main': {'temp': 300.89,
#    'feels_like': 305.18,
#    'temp_min': 300.89,
#    'temp_max': 300.89,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1013,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 6},
#   'wind': {'speed': 9.06, 'deg': 196, 'gust': 11.03},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-25 09:00:00'},
#  {'dt': 1779710400,
#   'main': {'temp': 300.99,
#    'feels_like': 305.45,
#    'temp_min': 300.99,
#    'temp_max': 300.99,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1012,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 4},
#   'wind': {'speed': 8.6, 'deg': 206, 'gust': 10.31},
#   'visibility': 10000,
#   'pop': 0.38,
#   'rain': {'3h': 0.18},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-05-25 12:00:00'}]

# %% [markdown]
# Starting from your `paris_forecasts` variable and using a for loop, create 2 variables named `times` and `maxs` that will respectively store the forecast datetimes and maximum temperatures of Paris.

# %%
times = []
for i in paris_forecasts:
  times.append(i["dt_txt"])

maxs = []
for i in paris_forecasts:
  maxs.append(i["main"]["temp_max"])
times
# Out:
# ['2026-05-20 15:00:00',
#  '2026-05-20 18:00:00',
#  '2026-05-20 21:00:00',
#  '2026-05-21 00:00:00',
#  '2026-05-21 03:00:00',
#  '2026-05-21 06:00:00',
#  '2026-05-21 09:00:00',
#  '2026-05-21 12:00:00',
#  '2026-05-21 15:00:00',
#  '2026-05-21 18:00:00',
#  '2026-05-21 21:00:00',
#  '2026-05-22 00:00:00',
#  '2026-05-22 03:00:00',
#  '2026-05-22 06:00:00',
#  '2026-05-22 09:00:00',
#  '2026-05-22 12:00:00',
#  '2026-05-22 15:00:00',
#  '2026-05-22 18:00:00',
#  '2026-05-22 21:00:00',
#  '2026-05-23 00:00:00',
#  '2026-05-23 03:00:00',
#  '2026-05-23 06:00:00',
#  '2026-05-23 09:00:00',
#  '2026-05-23 12:00:00',
#  '2026-05-23 15:00:00',
#  '2026-05-23 18:00:00',
#  '2026-05-23 21:00:00',
#  '2026-05-24 00:00:00',
#  '2026-05-24 03:00:00',
#  '2026-05-24 06:00:00',
#  '2026-05-24 09:00:00',
#  '2026-05-24 12:00:00',
#  '2026-05-24 15:00:00',
#  '2026-05-24 18:00:00',
#  '2026-05-24 21:00:00',
#  '2026-05-25 00:00:00',
#  '2026-05-25 03:00:00',
#  '2026-05-25 06:00:00',
#  '2026-05-25 09:00:00',
#  '2026-05-25 12:00:00']

# %% [markdown]
# Finally, store your 2 lists in a `paris_dict` dictionary, assigning them to 2 keys: `datetime` and `max_temperature`

# %%
paris_dict = {"datetime":times,"max_temperature":maxs}
paris_dict
# Out:
# {'datetime': ['2026-05-20 15:00:00',
#   '2026-05-20 18:00:00',
#   '2026-05-20 21:00:00',
#   '2026-05-21 00:00:00',
#   '2026-05-21 03:00:00',
#   '2026-05-21 06:00:00',
#   '2026-05-21 09:00:00',
#   '2026-05-21 12:00:00',
#   '2026-05-21 15:00:00',
#   '2026-05-21 18:00:00',
#   '2026-05-21 21:00:00',
#   '2026-05-22 00:00:00',
#   '2026-05-22 03:00:00',
#   '2026-05-22 06:00:00',
#   '2026-05-22 09:00:00',
#   '2026-05-22 12:00:00',
#   '2026-05-22 15:00:00',
#   '2026-05-22 18:00:00',
#   '2026-05-22 21:00:00',
#   '2026-05-23 00:00:00',
#   '2026-05-23 03:00:00',
#   '2026-05-23 06:00:00',
#   '2026-05-23 09:00:00',
#   '2026-05-23 12:00:00',
#   '2026-05-23 15:00:00',
#   '2026-05-23 18:00:00',
#   '2026-05-23 21:00:00',
#   '2026-05-24 00:00:00',
#   '2026-05-24 03:00:00',
#   '2026-05-24 06:00:00',
#   '2026-05-24 09:00:00',
#   '2026-05-24 12:00:00',
#   '2026-05-24 15:00:00',
#   '2026-05-24 18:00:00',
#   '2026-05-24 21:00:00',
#   '2026-05-25 00:00:00',
#   '2026-05-25 03:00:00',
#   '2026-05-25 06:00:00',
#   '2026-05-25 09:00:00',
#   '2026-05-25 12:00:00'],
#  'max_temperature': [301.14,
#   301.08,
#   301.04,
#   301.06,
#   300.98,
#   300.98,
#   301.05,
#   300.92,
#   300.98,
#   301,
#   300.9,
#   300.79,
#   300.79,
#   300.91,
#   301,
#   300.86,
#   300.94,
#   300.94,
#   300.88,
#   300.76,
#   300.81,
#   300.83,
#   300.82,
#   300.98,
#   301.02,
#   301.01,
#   300.92,
#   300.9,
#   300.78,
#   300.8,
#   300.97,
#   301.1,
#   300.97,
#   300.94,
#   300.76,
#   300.34,
#   300.84,
#   300.87,
#   300.89,
#   300.99]}

# %% [markdown]
# ### Any city forecasts

# %% [markdown]
# Using every previous step, create a `get_forecasts` function that will take a city name as argument and return a dictionnary containing the forecast datetimes and maximum temperatures. 🚀

# %%
def get_forecasts(city_name):
  lat, lon = get_coordinates(city_name)
  city_forecasts = requests.get("https://weather.lewagon.com/data/2.5/forecast",params={"lat":lat,"lon":lon}).json()["list"]


  times = []
  for i in city_forecasts:
    times.append(i["dt_txt"])

  maxs = []
  for i in city_forecasts:
    maxs.append(i["main"]["temp_max"])

  return ({"datetime":times,"max_temperature":maxs})

print(get_forecasts("Lyon"))
# Out:
# {'datetime': ['2026-05-20 15:00:00', '2026-05-20 18:00:00', '2026-05-20 21:00:00', '2026-05-21 00:00:00', '2026-05-21 03:00:00', '2026-05-21 06:00:00', '2026-05-21 09:00:00', '2026-05-21 12:00:00', '2026-05-21 15:00:00', '2026-05-21 18:00:00', '2026-05-21 21:00:00', '2026-05-22 00:00:00', '2026-05-22 03:00:00', '2026-05-22 06:00:00', '2026-05-22 09:00:00', '2026-05-22 12:00:00', '2026-05-22 15:00:00', '2026-05-22 18:00:00', '2026-05-22 21:00:00', '2026-05-23 00:00:00', '2026-05-23 03:00:00', '2026-05-23 06:00:00', '2026-05-23 09:00:00', '2026-05-23 12:00:00', '2026-05-23 15:00:00', '2026-05-23 18:00:00', '2026-05-23 21:00:00', '2026-05-24 00:00:00', '2026-05-24 03:00:00', '2026-05-24 06:00:00', '2026-05-24 09:00:00', '2026-05-24 12:00:00', '2026-05-24 15:00:00', '2026-05-24 18:00:00', '2026-05-24 21:00:00', '2026-05-25 00:00:00', '2026-05-25 03:00:00', '2026-05-25 06:00:00', '2026-05-25 09:00:00', '2026-05-25 12:00:00'], 'max_temperature': [302.17, 301.84, 299.71, 296.91, 296.17, 300.88, 304.64, 306.03, 304.64, 302.58, 298.04, 297.21, 296.21, 300.88, 305.5, 307.29, 305.31, 301.76, 298.67, 297.08, 296.57, 300.47, 305.16, 307.45, 303.73, 301.06, 298.07, 296.79, 296.27, 300.93, 305.62, 306.77, 305.04, 300.9, 298.04, 296.77, 296.77, 300.4, 305.31, 307.12]}

# %% [markdown]
# Congratulations ! 🎉 \
# You have now created a powerful function that can give you hourly temperature forecasts thanks to some API calls !

# %% [markdown]
# ### Bonus : Visualization

# %% [markdown]
# Run the following lines of code to plot the temperature forecasts for various cities accross the globe 🌍 \
# Don't worry about about the `plotly.express` library, we will cover it in the next lecture.

# %%
import pandas as pd
import plotly.express as px

cities = ["Paris","London","Lisbon","New York","Cape Town", "Madrid"] # Feel free to add or remove some cities

df=pd.DataFrame()

for city in cities:

    city_df=pd.DataFrame(get_forecasts(city))
    city_df['datetime']=pd.to_datetime(city_df['datetime'])
    city_df.set_index('datetime',inplace=True)
    city_df.columns=[city]
    df=pd.concat([df,city_df],axis=1)


px.line(df)
